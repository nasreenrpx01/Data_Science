# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Despcriptive Analysis

# %%
df=pd.read_csv("sales_data_with_discounts.csv") # Loading dataset

# %%
df.head() #Getting preview of the data
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
df[df.duplicated()] #no duplicates
# Out:
# Empty DataFrame
# Columns: [Date, Day, SKU, City, Volume, BU, Brand, Model, Avg Price, Total Sales Value, Discount Rate (%), Discount Amount, Net Sales Value]
# Index: []

# %%
df.Brand.value_counts()
# Out:
# Brand
# Jeera      90
# Gear       60
# Viva       60
# RealU      45
# YouM       45
# Babaji     45
# Vedic      45
# Sumsang    30
# Orange     30
# Name: count, dtype: int64

# %%
df.groupby('Brand')[['Avg Price']].describe()
# Out:
#         Avg Price                                                        \
#             count          mean          std      min      25%      50%
# Brand
# Babaji       45.0    385.000000    73.042640    290.0    290.0    400.0
# Gear         60.0    639.750000   273.527220    400.0    475.0    530.0
# Jeera        90.0   1558.166667   936.254866    450.0    500.0   1600.0
# Orange       30.0  57600.000000  2542.738139  55100.0  55100.0  57600.0
# RealU        45.0  10100.000000  1651.445648   8100.0   8100.0  10100.0
# Sumsang      30.0  51600.000000  2542.738139  49100.0  49100.0  51600.0
# Vedic        45.0    380.000000    62.340706    300.0    300.0    390.0
# Viva         60.0   1600.000000   633.794064    900.0   1200.0   1450.0
# YouM         45.0  14766.666667  5045.249791   8100.0   8100.0  16100.0
#
#
#               75%      max
# Brand
# Babaji     465.00    465.0
# Gear       694.75   1099.0
# Jeera     2099.00   3100.0
# Orange   60100.00  60100.0
# ...

# %%
df.info() 
#as we can see we got no null values,6-numerical columns and 7 non numerical columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
df.shape #13 columns and 450 entries
# Out:
# (450, 13)

# %%
df.describe() #getting desscriptive statistics of all numerical columns
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
v=df['Avg Price'].var() #Finding the variance in a single column

# %%
print(f'The Variance in Average price is {round(v,4)}')
# Out:
# The Variance in Average price is 326882959.0212

# %%
 Skew=df.skew(numeric_only=True) #Getting Skewness of all numeric columns

# %%
df.kurt(numeric_only=True) #Getting Kurtosis of all numeric columns
# Out:
# Volume               10.258547
# Avg Price             2.075655
# Total Sales Value     1.024916
# Discount Rate (%)    -0.178541
# Discount Amount       3.831186
# Net Sales Value       1.012468
# dtype: float64

# %%
df.BU.value_counts() #Seeing the type of Bu in Dataset and their no.of entries
# Out:
# BU
# Mobiles      150
# FMCG         150
# Lifestyle    150
# Name: count, dtype: int64

# %%
df.ndim #Getting the dimensions of the dataset
# Out:
# 2

# %%
df.groupby('Date')[['Total Sales Value','Volume']].describe() #Getting statistics based on dates
# Out:
#            Total Sales Value                                               \
#                        count          mean           std     min      25%
# Date
# 01-04-2021              30.0  39996.533333  59379.346202   560.0  2687.50
# 02-04-2021              30.0  37648.833333  57241.203222   400.0  2355.00
# 03-04-2021              30.0  28616.766667  45163.807867  1120.0  3300.00
# 04-04-2021              30.0  32971.900000  47682.468218  1099.0  2825.00
# 05-04-2021              30.0  30106.466667  47034.940191   800.0  2124.50
# 06-04-2021              30.0  32177.666667  46833.029935   400.0  3105.00
# 07-04-2021              30.0  38535.633333  60489.493289   580.0  3422.75
# 08-04-2021              30.0  34476.366667  50347.964959   800.0  3162.50
# 09-04-2021              30.0  35594.133333  53821.099661   800.0  2632.50
# 10-04-2021              30.0  30120.766667  44657.307002   870.0  2049.50
# 11-04-2021              30.0  36226.700000  55466.667828   600.0  3149.25
# ...

# %%
df['City'].value_counts() #only one city found 'C'
# Out:
# City
# C    450
# Name: count, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
sns.kdeplot(df)
plt.title("Kurtosis Plot")
plt.xlim(-10,35)
plt.xlabel('Value')
plt.show()

# %%
Skew
# Out:
# Volume               2.731724
# Avg Price            1.908873
# Total Sales Value    1.534729
# Discount Rate (%)   -1.062294
# Discount Amount      1.913038
# Net Sales Value      1.540822
# dtype: float64

# %%
plt.figure(figsize=(8, 6))
plt.bar(Skew.index, Skew.values, edgecolor='black')
plt.title('Skewness of Columns')
plt.xlabel('Columns')
plt.ylabel('Skewness')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines
plt.show()

# %%
plt.hist(x=df['Date'], weights=df['Total Sales Value'], bins=15,edgecolor='Blue')
plt.title('Histogram of Total Sales Value')
plt.xlabel('Date')
plt.ylabel('Total Sales Value')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines
plt.show()

# %%
plt.hist(x=df['Date'], weights=df['Net Sales Value'], bins=15,edgecolor='Blue',color='lightgreen')
plt.title('Histogram of Total Sales Value')
plt.xlabel('Date')
plt.ylabel('Net Sales Value')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines
plt.show()

# %%
plt.hist(x=df['Date'], weights=df['Volume'],bins=10,edgecolor='black')
plt.title("Histogram of Volumnes sold per Day")
plt.ylabel('Volumes Per Day')
plt.xlabel("Date")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines
plt.show()

# %%
df.groupby('Model')[['Volume','Avg Price']].describe()
# Out:
#                Volume                                                    \
#                 count       mean       std  min   25%   50%   75%   max
# Model
# Babaji Cream     15.0   5.266667  1.791514  2.0   4.0   5.0   7.0   8.0
# Babaji Oil       15.0  18.400000  9.310516  2.0  13.5  22.0  24.5  31.0
# Babaji Shampoo   15.0   6.133333  2.642149  2.0   4.0   6.0   8.0  11.0
# Gear BB Cream    15.0   2.866667  0.990430  1.0   2.5   3.0   3.5   4.0
# Gear Cream       15.0   2.333333  0.816497  1.0   2.0   2.0   3.0   4.0
# Gear Oil         15.0   3.466667  0.833809  2.0   3.0   4.0   4.0   5.0
# Gear Shampoo     15.0   2.400000  0.736788  1.0   2.0   2.0   3.0   4.0
# M- Inners        15.0   6.866667  2.774029  3.0   5.0   7.0   9.0  12.0
# M- T Shirts      15.0  11.000000  3.443420  4.0  10.0  12.0  13.0  16.0
# M-Casuals        15.0   3.933333  1.162919  2.0   3.0   4.0   4.5   6.0
# M-Formals        15.0   2.333333  0.816497  1.0   2.0   3.0   3.0   3.0
# ...

# %%
top_n_brands = df['Brand'].value_counts().nlargest(10)
plt.figure(figsize=(10, 6))
top_n_brands.plot(kind='bar', color='skyblue',edgecolor="Black")
plt.title('Top Brands by Frequency')
plt.xlabel('Brand')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines
plt.xticks(rotation=45)
plt.show()

# %%
# Grouping by 'Brand' and summing the 'Volume' for each brand
brand_volume = df.groupby('Brand')['Volume'].sum()

# Plotting the bar plot
plt.figure(figsize=(10, 6))
plt.bar(brand_volume.index, brand_volume.values, edgecolor='black', color='pink')
plt.title('Total Volume of Sales by Brand')
plt.xlabel('Brand')
plt.ylabel('Total Volume')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines
plt.show()

# %%
plt.boxplot(df['Net Sales Value'])
plt.title("Boxplot of Net sales Value")
plt.ylabel("Sales Values")
plt.grid(linestyle='-',alpha=0.8)
plt.show()#many outliers were found in this column

# %%
df[df['Net Sales Value']>120000].head(10) # 34 Outliers detected from boxplot figure above
# Out:
#            Date       Day  SKU City  Volume       BU    Brand  Model  \
# 0    01-04-2021  Thursday  M01    C      15  Mobiles    RealU  RU-10
# 6    01-04-2021  Thursday  M07    C       3  Mobiles  Sumsang   S-20
# 9    01-04-2021  Thursday  M10    C       3  Mobiles   Orange   O-11
# 36   02-04-2021    Friday  M07    C       3  Mobiles  Sumsang   S-20
# 38   02-04-2021    Friday  M09    C       3  Mobiles   Orange   O-10
# 39   02-04-2021    Friday  M10    C       3  Mobiles   Orange   O-11
# 66   03-04-2021  Saturday  M07    C       4  Mobiles  Sumsang   S-20
# 96   04-04-2021    Sunday  M07    C       3  Mobiles  Sumsang   S-20
# 126  05-04-2021    Monday  M07    C       3  Mobiles  Sumsang   S-20
# 127  05-04-2021    Monday  M08    C       3  Mobiles  Sumsang   S-21
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        12100             181500          11.654820     21153.498820
# ...

# %%
plt.boxplot(df['Total Sales Value'])
plt.title("Boxplot of Total Sales Value")
plt.ylabel('Sales Value')
plt.grid(linestyle='-', alpha=0.6)
plt.show()

# %%
df[df['Total Sales Value']>126000].head(10) #36 outliers detected from boxplot figure above
# Out:
#            Date       Day  SKU City  Volume       BU    Brand  Model  \
# 0    01-04-2021  Thursday  M01    C      15  Mobiles    RealU  RU-10
# 6    01-04-2021  Thursday  M07    C       3  Mobiles  Sumsang   S-20
# 9    01-04-2021  Thursday  M10    C       3  Mobiles   Orange   O-11
# 30   02-04-2021    Friday  M01    C      11  Mobiles    RealU  RU-10
# 36   02-04-2021    Friday  M07    C       3  Mobiles  Sumsang   S-20
# 38   02-04-2021    Friday  M09    C       3  Mobiles   Orange   O-10
# 39   02-04-2021    Friday  M10    C       3  Mobiles   Orange   O-11
# 66   03-04-2021  Saturday  M07    C       4  Mobiles  Sumsang   S-20
# 96   04-04-2021    Sunday  M07    C       3  Mobiles  Sumsang   S-20
# 126  05-04-2021    Monday  M07    C       3  Mobiles  Sumsang   S-20
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        12100             181500          11.654820     21153.498820
# ...

# %%
plt.boxplot(df['Avg Price'])
plt.title("Boxplot of Avg Price")
plt.ylabel('Price')
plt.grid(linestyle='-', alpha=0.6)
plt.show()# there are many outliers present in this column

# %%
df[df['Avg Price']>48000].head(10)  # 60 outliers were detected by the boxplot fig above
# Out:
#           Date       Day  SKU City  Volume       BU    Brand Model  Avg Price  \
# 6   01-04-2021  Thursday  M07    C       3  Mobiles  Sumsang  S-20      49100
# 7   01-04-2021  Thursday  M08    C       2  Mobiles  Sumsang  S-21      54100
# 8   01-04-2021  Thursday  M09    C       2  Mobiles   Orange  O-10      55100
# 9   01-04-2021  Thursday  M10    C       3  Mobiles   Orange  O-11      60100
# 36  02-04-2021    Friday  M07    C       3  Mobiles  Sumsang  S-20      49100
# 37  02-04-2021    Friday  M08    C       1  Mobiles  Sumsang  S-21      54100
# 38  02-04-2021    Friday  M09    C       3  Mobiles   Orange  O-10      55100
# 39  02-04-2021    Friday  M10    C       3  Mobiles   Orange  O-11      60100
# 66  03-04-2021  Saturday  M07    C       4  Mobiles  Sumsang  S-20      49100
# 67  03-04-2021  Saturday  M08    C       1  Mobiles  Sumsang  S-21      54100
#
#     Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value
# ...

# %%
plt.boxplot(df['Discount Rate (%)'])
plt.title("Boxplot of Discount Rate (%)")
plt.ylabel('Discount Rate (%)')
plt.grid(linestyle='-', alpha=0.6)
plt.show()# there are many outliers from the lower quartile

# %%
df[df['Discount Rate (%)']<8].head(10) #51 outliers were detected by the boxplot in above figure
# Out:
#           Date       Day  SKU City  Volume       BU    Brand       Model  \
# 3   01-04-2021  Thursday  M04    C       6  Mobiles     YouM  YM-99 Plus
# 7   01-04-2021  Thursday  M08    C       2  Mobiles  Sumsang        S-21
# 8   01-04-2021  Thursday  M09    C       2  Mobiles   Orange        O-10
# 33  02-04-2021    Friday  M04    C       6  Mobiles     YouM  YM-99 Plus
# 36  02-04-2021    Friday  M07    C       3  Mobiles  Sumsang        S-20
# 67  03-04-2021  Saturday  M08    C       1  Mobiles  Sumsang        S-21
# 69  03-04-2021  Saturday  M10    C       2  Mobiles   Orange        O-11
# 93  04-04-2021    Sunday  M04    C       6  Mobiles     YouM  YM-99 Plus
# 97  04-04-2021    Sunday  M08    C       2  Mobiles  Sumsang        S-21
# 98  04-04-2021    Sunday  M09    C       2  Mobiles   Orange        O-10
#
#     Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 3       20100             120600           6.935385      8364.074702
# ...

# %%
plt.boxplot(df['Discount Amount'])
plt.title("Boxplot of Discount Amount")
plt.ylabel('Discount Amount')
plt.grid(linestyle='-', alpha=0.6)
plt.show()# there are many outliers from the lower quartile

# %%
df[df['Discount Amount']> 12400].head(10) # 26 outliers were detected from the above boxplot figure
# Out:
#            Date       Day  SKU City  Volume       BU    Brand  Model  \
# 0    01-04-2021  Thursday  M01    C      15  Mobiles    RealU  RU-10
# 6    01-04-2021  Thursday  M07    C       3  Mobiles  Sumsang   S-20
# 9    01-04-2021  Thursday  M10    C       3  Mobiles   Orange   O-11
# 30   02-04-2021    Friday  M01    C      11  Mobiles    RealU  RU-10
# 38   02-04-2021    Friday  M09    C       3  Mobiles   Orange   O-10
# 39   02-04-2021    Friday  M10    C       3  Mobiles   Orange   O-11
# 66   03-04-2021  Saturday  M07    C       4  Mobiles  Sumsang   S-20
# 90   04-04-2021    Sunday  M01    C       9  Mobiles    RealU  RU-10
# 96   04-04-2021    Sunday  M07    C       3  Mobiles  Sumsang   S-20
# 126  05-04-2021    Monday  M07    C       3  Mobiles  Sumsang   S-20
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        12100             181500          11.654820     21153.498820
# ...

# %%
plt.boxplot(df['Volume'])
plt.title("Boxplot of Volume")
plt.ylabel('Volume')
plt.grid(linestyle='-', alpha=0.6)
plt.show()

# %%
df[df['Volume']>10].head(10) #40 outliers were detected from the above boxplot figure
# Out:
#            Date       Day  SKU City  Volume         BU   Brand        Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles   RealU        RU-10
# 10   01-04-2021  Thursday  F01    C      13       FMCG  Babaji  Babaji Oil
# 30   02-04-2021    Friday  M01    C      11    Mobiles   RealU        RU-10
# 40   02-04-2021    Friday  F01    C      29       FMCG  Babaji  Babaji Oil
# 50   02-04-2021    Friday  L01    C      13  Lifestyle   Jeera  M- T Shirts
# 70   03-04-2021  Saturday  F01    C      24       FMCG  Babaji  Babaji Oil
# 71   03-04-2021  Saturday  F02    C      14       FMCG   Vedic  Vedic Cream
# 80   03-04-2021  Saturday  L01    C      12  Lifestyle   Jeera  M- T Shirts
# 100  04-04-2021    Sunday  F01    C      25       FMCG  Babaji  Babaji Oil
# 101  04-04-2021    Sunday  F02    C      15       FMCG   Vedic  Vedic Cream
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %% [markdown]
# # Standardization of Numerical Variables

# %%
# Before standardization (showing the original data distribution)
print("Before Standardization:")
print(df.describe())

# Standardization
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
df_standardized = df.copy()
for column in numerical_columns:
    mean = df[column].mean()
    std = df[column].std()
    df_standardized[column] = (df[column] - mean) / std

# After standardization (showing the standardized data distribution)
print("\nAfter Standardization:")
print(df_standardized.describe())
# Out:
# Before Standardization:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# ...
